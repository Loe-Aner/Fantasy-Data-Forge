# %%
import sys # aby importy z dołu działały
sys.path.append(r"D:\MyProjects_4Fun\projects\World of Warcraft\python-etl")

# %%
from moduly.db_admin import czerwony_przycisk, zielony_przycisk
from moduly.db_core import utworz_engine_do_db

# %%
silnik = utworz_engine_do_db()

# %%
czerwony_przycisk(silnik)
zielony_przycisk(silnik)
# Out:
# Baza danych... już nie istnieje. Zadowolony jesteś z siebie?
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\1_tabela_NPC.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\2_tabela_misje.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\3_tabela_zrodlo.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\4_tabela_NPC_statusy.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\5_tabela_misje_statusy.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\6_tabela_dialogi.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\7_tabela_linki_do_scrapowania.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\8_tabela_slowa_kluczowe.sql
# Postawiono tabelę w: D:\MyProjects_4Fun\projects\World of Warcraft\sql-tabele\9_tabela_misje_slowa_kluczowe.sql
